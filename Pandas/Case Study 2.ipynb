# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cerealdf= pd.read_csv("C:/Users/91758/Downloads/cereal.csv")

# %%
cerealdf.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
plt.hist(cerealdf['sugars'])
# Out:
# (array([ 8.,  4., 13.,  6.,  7.,  9.,  9.,  5., 11.,  5.]),
#  array([-1. ,  0.6,  2.2,  3.8,  5.4,  7. ,  8.6, 10.2, 11.8, 13.4, 15. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(cerealdf['vitamins'])
plt.show()

# %%
cerealdf['mfr'].replace({'N': 'Nabisco','Q': 'Quaker Oats','K': 'Kelloggs','R': 'Raslston Purina','G': 'General Mills' ,'P' :'Post' ,'A':'American Home Foods Products'},inplace=True)

# %%
cerealdf
# Out:
#                                       name              mfr type  calories  \
# 0                                100% Bran          Nabisco    C        70
# 1                        100% Natural Bran      Quaker Oats    C       120
# 2                                 All-Bran         Kelloggs    C        70
# 3                All-Bran with Extra Fiber         Kelloggs    C        50
# 4                           Almond Delight  Raslston Purina    C       110
# 5                  Apple Cinnamon Cheerios    General Mills    C       110
# 6                              Apple Jacks         Kelloggs    C       110
# 7                                  Basic 4    General Mills    C       130
# 8                                Bran Chex  Raslston Purina    C        90
# 9                              Bran Flakes             Post    C        90
# 10                            Cap'n'Crunch      Quaker Oats    C       120
# ...

# %%
s=cerealdf['mfr'].value_counts()

# %%
Cdf= pd.DataFrame(s)

# %%
Cdf.reset_index(inplace=True)

# %%
Cdf
# Out:
#                           index  mfr
# 0                      Kelloggs   23
# 1                 General Mills   22
# 2                          Post    9
# 3               Raslston Purina    8
# 4                   Quaker Oats    8
# 5                       Nabisco    6
# 6  American Home Foods Products    1

# %%
plt.barh(Cdf['index'],Cdf['mfr'])
# Out:
# <BarContainer object of 7 artists>

# %%
x=cerealdf[['calories','protein','fat','sodium','fiber','carbo','sugars','potass','vitamins','shelf','weight','cups']]

# %%
y=cerealdf[['rating']]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.75, test_size = 0.25)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_predict = lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 2.992076052180428e-13
