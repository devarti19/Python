# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
prisonersdf= pd.read_csv("C:/Users/91758/Downloads/prisoners.csv")

# %%
prisonersdf.head()
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# ...

# %%
prisonersdf.tail()
# Out:
#         STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 30  D & N Haveli  2013                                                  0
# 31   Daman & Diu  2013                                                  0
# 32         Delhi  2013                                               1458
# 33   Lakshadweep  2013                                                  0
# 34   Pondicherry  2013                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 30                                             0
# 31                                             0
# 32                                          1187
# 33                                             0
# 34                                             0
#
#     No. of Inmates benefitted by Higher Education  \
# 30                                              0
# 31                                              0
# 32                                            908
# ...

# %%
prisonersdf.describe()
# Out:
#          YEAR  No. of Inmates benefitted by Elementary Education  \
# count    35.0                                          35.000000
# mean   2013.0                                        1057.914286
# std       0.0                                        2078.196777
# min    2013.0                                           0.000000
# 25%    2013.0                                           0.000000
# 50%    2013.0                                         167.000000
# 75%    2013.0                                        1294.500000
# max    2013.0                                        9480.000000
#
#        No. of Inmates benefitted by Adult Education  \
# count                                     35.000000
# mean                                    1534.857143
# std                                     3022.110503
# min                                        0.000000
# 25%                                        6.500000
# 50%                                      237.000000
# ...

# %%
prisonersdf['total_benefitted']=prisonersdf[['No. of Inmates benefitted by Elementary Education','No. of Inmates benefitted by Adult Education','No. of Inmates benefitted by Higher Education','No. of Inmates benefitted by Computer Course']].sum(axis=1)

# %%
prisonersdf
# Out:
#              STATE/UT  YEAR  \
# 0      Andhra Pradesh  2013
# 1   Arunachal Pradesh  2013
# 2               Assam  2013
# 3               Bihar  2013
# 4         Chhatisgarh  2013
# 5                 Goa  2013
# 6             Gujarat  2013
# 7             Haryana  2013
# 8    Himachal Pradesh  2013
# 9     Jammu & Kashmir  2013
# 10          Jharkhand  2013
# 11          Karnataka  2013
# 12             Kerala  2013
# 13     Madhya Pradesh  2013
# 14        Maharashtra  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 19             Orissa  2013
# 20             Punjab  2013
# 21          Rajasthan  2013
# 22             Sikkim  2013
# 23          Tamilnadu  2013
# 24            Tripura  2013
# 25      Uttar Pradesh  2013
# 26        Uttaranchal  2013
# 27        West Bengal  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# ...

# %%
prisonersdf.loc['totals']= prisonersdf.sum()

# %%
prisonersdf
# Out:
#                                                  STATE/UT   YEAR  \
# 0                                          Andhra Pradesh   2013
# 1                                       Arunachal Pradesh   2013
# 2                                                   Assam   2013
# 3                                                   Bihar   2013
# 4                                             Chhatisgarh   2013
# 5                                                     Goa   2013
# 6                                                 Gujarat   2013
# 7                                                 Haryana   2013
# 8                                        Himachal Pradesh   2013
# 9                                         Jammu & Kashmir   2013
# 10                                              Jharkhand   2013
# 11                                              Karnataka   2013
# 12                                                 Kerala   2013
# ...

# %%
plt.bar(prisonersdf['STATE/UT'],prisonersdf['total_benefitted'])
plt.show()

# %%
labels='No. of Inmates benefitted by Elementary Education','No. of Inmates benefitted by Adult Education','No. of Inmates benefitted by Higher Education','No. of Inmates benefitted by Computer Course'

# %%
size= prisonersdf.loc['totals',['No. of Inmates benefitted by Elementary Education','No. of Inmates benefitted by Adult Education','No. of Inmates benefitted by Higher Education','No. of Inmates benefitted by Computer Course']]

# %%
plt.pie(size,labels=labels)
plt.show()
